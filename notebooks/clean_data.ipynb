# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
base = pd.read_excel('sample_-_superstore.xls')

# %%
base.head()

# %%
#remover duplicatas
base.drop_duplicates()

# %%
#converter datas
base['Order Date'] = pd.to_datetime(base['Order Date'])
base['Ship Date'] = pd.to_datetime(base['Ship Date'])

# %%
base.head()

# %%
base.info()

# %%
base.isnull().sum()

# %%
base.duplicated().sum()

# %%
#salvar a base limpa no formato csv
base.to_csv('superstore_clean.csv', index=False)
